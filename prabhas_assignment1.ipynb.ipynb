# %%
text="Edukron Data Science and Data Engineering Batch 2026"
print(text[0:8])
print(text[-52:-45])
print(text[8:12])
print(text[-44:-40])
print(text[13:20])
print(text[-39:-32])
print(text[21:24])
print(text[-31:-28])
print(text[25:41])
print(text[-27:-11])
print(text[30:41])
print(text[-22:-11])
print(text[42:47])
print(text[-10:-5])
print(text[48:52])
print(text[-4:])
print(text[13:29])
print(text[-39:-23])
print(text[8:47])
# Out:
# Edukron
# Edukron
# Data
# Data
# Science
# Science
# and
# and
# Data Engineering
# Data Engineering
# Engineering
# Engineering
# Batch
# Batch
# 2026
# 2026
# Science and Data
# Science and Data
# Data Science and Data Engineering Batch
