# %%
bank = [ [ [ ["C101", "Rahul", "Savings", 85000], ["C102", "Anita", "Current", 150000], ["C103", "Kiran", "Loan", 500000] ], [ ["C104", "Sneha", "Savings", 95000], ["C105", "Vikram", "Current", 275000], ["C106", "Meena", "Loan", 750000] ] ],

[
    [
        ["C201", "Arjun", "Savings", 120000],
        ["C202", "Pooja", "Current", 325000],
        ["C203", "Ramesh", "Loan", 900000]
    ],
    [
        ["C204", "Priya", "Savings", 45000],
        ["C205", "Amit", "Current", 185000],
        ["C206", "Divya", "Loan", 650000]
    ]
],

[
    [
        ["C301", "Nikhil", "Savings", 78000],
        ["C302", "Kavya", "Current", 240000],
        ["C303", "Suresh", "Loan", 1000000]
    ],
    [
        ["C304", "Neha", "Savings", 135000],
        ["C305", "Rohan", "Current", 410000],
        ["C306", "Asha", "Loan", 550000]
    ]
]
]

# %%
print(bank[0][0][0])
# Out:
# ['C101', 'Rahul', 'Savings', 85000]

# %%
print(bank[0][0][1][2])
# Out:
# Current

# %%
print(bank[0][0][2][3])
# Out:
# 500000

# %%
print(bank[0][1][0][0])
# Out:
# C104

# %%
print(bank[0][1][1][3])
# Out:
# 275000

# %%
print(bank[0][1][2])
# Out:
# ['C106', 'Meena', 'Loan', 750000]

# %%
print(bank[1][0][0][0])
# Out:
# C201

# %%
print(bank[1][0][1][1])
# Out:
# Pooja

# %%
print(bank[1][0][2][2])
# Out:
# Loan

# %%
print(bank[1][1][0][3])
# Out:
# 45000

# %%
print(bank[1][1][1][2])
# Out:
# Current

# %%
print(bank[2][0][0][2])
# Out:
# Savings

# %%
print(bank[2][0][1][3])
# Out:
# 240000

# %%
print(bank[2][0][2][3])
# Out:
# 1000000

# %%
print(bank[2][1][0][1])
# Out:
# Neha

# %%
print(bank[2][1][1])
# Out:
# ['C305', 'Rohan', 'Current', 410000]

# %%
print(bank[2][1][2][2])
# Out:
# Loan

# %%
print(bank[0][0])
# Out:
# [['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]]

# %%
print(bank[0][1])
# Out:
# [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]

# %%
print(bank[1][0])
# Out:
# [['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]]

# %%
print(bank[1][0])
# Out:
# [['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]]

# %%
print(bank[1][1])
# Out:
# [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]

# %%
print(bank[2][0])
# Out:
# [['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]]

# %%
print(bank[2][1])
# Out:
# [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]

# %%
print(bank[0])
# Out:
# [[['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]], [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]]

# %%
print(bank[1])
# Out:
# [[['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]], [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]]

# %%
print(bank[2])
# Out:
# [[['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]], [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]]

# %%
print(bank[0][0][0])
print(bank[1][0][0])
print(bank[2][0][0])
# Out:
# ['C101', 'Rahul', 'Savings', 85000]
# ['C201', 'Arjun', 'Savings', 120000]
# ['C301', 'Nikhil', 'Savings', 78000]

# %%
print(bank[0][1][1])
print(bank[1][1][1])
print(bank[2][1][1])
# Out:
# ['C105', 'Vikram', 'Current', 275000]
# ['C205', 'Amit', 'Current', 185000]
# ['C305', 'Rohan', 'Current', 410000]

# %%
print(bank[2][1][2][3])
# Out:
# 550000

# %%
employees=["Rahul","Anitha","kiran","Sneha","Vikram"]
employees.append("Arjun")
print(employees)
# Out:
# ['Rahul', 'Anitha', 'kiran', 'Sneha', 'Vikram', 'Arjun']

# %%
account_numbers=[101,102,103]
account_numbers.extend([104,105,106])
print(account_numbers)
# Out:
# [101, 102, 103, 104, 105, 106]

# %%
customers=["Rahul","Anitha","Kiran"]
customers.insert(0,"Arjun")
print(customers)
# Out:
# ['Arjun', 'Rahul', 'Anitha', 'Kiran']

# %%
transactions=[1000,2000,3000,5000]
transactions.insert(3,4000)
print(transactions)
# Out:
# [1000, 2000, 3000, 4000, 5000]

# %%
customers=["Rahul","Anitha","Kiran","Sneha"]
customers.pop()
print(customers)
# Out:
# ['Rahul', 'Anitha', 'Kiran']

# %%
customers=["Rahul","Anitha","Kiran","Sneha"]
customers.remove("Rahul")
print(customers)
# Out:
# ['Anitha', 'Kiran', 'Sneha']

# %%
account_types=["Savings","Current","Savings","loan","Savings"]
print(account_types.count("Savings"))
# Out:
# 3

# %%
account_types=["Savings","Current","Loan"]
print(account_types.index("Current"))
# Out:
# 1

# %%
transaction_ids=[101,102,103,104,105]
transaction_ids.reverse()
print(transaction_ids)
# Out:
# [105, 104, 103, 102, 101]

# %%
balances=[85000,120000,45000,95000,275000]
balances.sort()
print(balances)
# Out:
# [45000, 85000, 95000, 120000, 275000]

# %%
customers=["Rahul","Anitha","Kiran","Sneha","Vikram"]
customers.sort(reverse=True)
print(customers)
# Out:
# ['Vikram', 'Sneha', 'Rahul', 'Kiran', 'Anitha']

# %%
customers=["Rahul","Anitha","Kiran"]
copy_customers=customers.copy()
print("Original:",customers)
print("Copy:",copy_customers)
# Out:
# Original: ['Rahul', 'Anitha', 'Kiran']
# Copy: ['Rahul', 'Anitha', 'Kiran']

# %%
customers=["Rahul","Anitha","Kiran"]
customers.clear()
print(customers)
# Out:
# []

# %%
customers=["C101","Rahul","Savings",85000]
customers.append(["C102","Anitha","Current",150000])
print(customers)
# Out:
# ['C101', 'Rahul', 'Savings', 85000, ['C102', 'Anitha', 'Current', 150000]]

# %%
branches=["MG Road","Indira Nagar",]
new_branches=["White Field","Electronic City"]
branches.extend(new_branches)
print(branches)
# Out:
# ['MG Road', 'Indira Nagar', 'White Field', 'Electronic City']

# %%
balances=[50000,85000,50000,120000]
balances.remove(50000)
print(balances)
# Out:
# [85000, 50000, 120000]

# %%
numbers=[10,20,30,40,50]
removed=numbers.pop(2)
print("Removed:",removed)
print(numbers)
# Out:
# Removed: 30
# [10, 20, 40, 50]

# %%
cities=["Banglore","Hyderabad","Banglore","Chennai"]
print(cities.count("Banglore"))
# Out:
# 2

# %%
banks=["SBI","HDFC","ICICI","AXIS"]
banks.reverse()
print(banks)
# Out:
# ['AXIS', 'ICICI', 'HDFC', 'SBI']

# %%
loan_amounts=[500000,7500000,250000,1000000]
loan_amounts.sort(reverse=True)
print(loan_amounts)
# Out:
# [7500000, 1000000, 500000, 250000]
